# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from google.colab import files     
uploaded = files.upload()
# Out:
#      <input type="file" id="files-18975c73-e41d-4d6e-b806-05d498fa78ab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-18975c73-e41d-4d6e-b806-05d498fa78ab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv
#      <input type="file" id="files-398e6ca5-6101-4bd8-be7f-edcb7a1b8676" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-398e6ca5-6101-4bd8-be7f-edcb7a1b8676">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
df = pd.read_csv("data.csv") 
df.head()
# Out:
#             x           y  z
# 0  117.593042  101.377856  a
# 1   97.426863  116.344495  a
# 2   97.562923   73.212465  a
# 3   68.603151   39.308131  a
# 4   92.329087  111.695514  a

# %%
x = df['x'].values
y = df['y'].values

x_mean = np.mean(x)
y_mean = np.mean(y)

n = len(x)

num = 0
den = 0


for i in range(n):
  num += (x[i] - x_mean) * (y[i] - y_mean)
  den += (x[i] - x_mean) ** 2

b1 = num / den
b0 = y_mean - (b1 * x_mean)

print(b0, b1)
# Out:
# 83.02585688668515 0.4912903343161823

# %%
x = df['x'].values
y = df['y'].values

x_max = np.max(x)
x_min = np.min(x)



plt.plot(x, (b1 * x + b0), color='red')
plt.scatter(x, y)
plt.xlabel('-x-')
plt.ylabel('-y-')
plt.title('first')
plt.show()

# %%
#using linspace
x_max = np.max(x)
x_min = np.min(x)

X=np.linspace(x_min, x_max, 10)
Y=b0 + b1 * X

plt.plot(X, Y, color='red')
plt.scatter(x, y)
plt.xlabel('-x-')
plt.ylabel('-y-')
plt.title('first')
plt.show()
