# %% [markdown]
# importing numpy,pandas,linearregression model

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %% [markdown]
# data is in form of y=2x1+3x2+4x3+5

# %%
data=pd.read_csv('data.csv')

# %%
data
# Out:
#    x1  x2  x3    y
# 0 -94  24  22  -23
# 1  12  63  11  262
# 2  27  87  23  412
# 3  56   9   6  168
# 4  66  12  76  477
# 5  78   1  53  376
# 6  25  23  91  488
# 7  98  43   2  338
# 8  45  32   0  191
# 9  21  11   2   88

# %%
x=data[['x1','x2','x3']].values

# %%
x
# Out:
# array([[-94,  24,  22],
#        [ 12,  63,  11],
#        [ 27,  87,  23],
#        [ 56,   9,   6],
#        [ 66,  12,  76],
#        [ 78,   1,  53],
#        [ 25,  23,  91],
#        [ 98,  43,   2],
#        [ 45,  32,   0],
#        [ 21,  11,   2]])

# %%
y=data[['y']].values
y
# Out:
# array([[-23],
#        [262],
#        [412],
#        [168],
#        [477],
#        [376],
#        [488],
#        [338],
#        [191],
#        [ 88]])

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# the intercept of the equation is 5

# %%
model.intercept_
# Out:
# array([5.])

# %% [markdown]
# the coefficients of x1=2,x2=3,x3=4

# %%
model.coef_
# Out:
# array([[2., 3., 4.]])

# %%
y_predict=model.predict(x)

# %%
y_predict
# Out:
# array([[-23.],
#        [262.],
#        [412.],
#        [168.],
#        [477.],
#        [376.],
#        [488.],
#        [338.],
#        [191.],
#        [ 88.]])

# %% [markdown]
# if x1=3,x2=2,x3=1 then y should be 21 according to the equation y=2x1+3x2+4x3+5

# %%
x_new=np.array([[3,  2,  1]])

# %%
y_new=model.predict(x_new)

# %%
y_new
# Out:
# array([[21.]])
